# %%
list1=["ayush",'rahul','choco']
print("ayush" in list1)
print("lolo" in list1)
print("hola" not in list1)
# Out:
# True
# False
# True

# %%
a=[1,2,3]
b=[4,5,6]
c=a+b
print(c)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
b=10
print(b in c)
# Out:
# False

# %%
#TYPECASTING
print(int(3.5))   #o/p=3
print(int("5"))   #o/p=5
#print(int("3.5"))
#print(int("6+2j"))
print(int(3))
# Out:
# 3
# 5
# 3

# %%
#COMPLEX
a=2
b=3
res=complex(a,b)
print(res)
print(complex(3))
print(complex(True))
print(complex(False))
print(complex(True,True))

# %%
import math as m
r=5
ar=m.pi*(r**2)
print("area of circle",ar)
# Out:
# area of circle 78.53981633974483

# %%
a=int(input("Enter a Value:"))
b=int(input("Enter b Value:"))
print(a+b)
# Out:
# Enter a Value:2
# Enter b Value:3
# 5

# %%
print(int(input("Enter a Value:")) + int(input("Enter b Value:")))
# Out:
# Enter a Value:6
# Enter b Value:3
# 9

# %%
expression = "2 + 3 * 4"
result = eval(expression)
print(f"Result of '{expression}': {result}")


x = 5
y = 10
expression = "x * y + 2"
result = eval(expression)
print(f"Result of '{expression}': {result}")
l
expression = "len('hello')"
result = eval(expression)
print(f"Result of '{expression}': {result}")


expression = "math.sqrt(16)"
result = eval(expression)
print(f"Result of '{expression}': {result}")

# %%
print('hello \n world')
# Out:
# hello
#  world

# %%
print('hello \t world')
# Out:
# hello 	 world

# %%
print("Hello \n World" )
print("Hello \t World")
print("Hello"+"World" )
print("Hello"*3)
# Out:
# Hello
#  World
# Hello 	 World
# HelloWorld
# HelloHelloHello

# %%
a=10
b=20
c=30
print(a,b,c)
a,b,c=10,20,30
print(a,b,c)
print(a,b,c,sep=":")
# Out:
# 10 20 30
# 10 20 30
# 10:20:30

# %%
print("Hello", end=" ")
print("Ashish", end=" ")
print("Sir")
# Out:
# Hello Ashish Sir

# %%
a=10
b=20
c=30
print("a value is %i" %a)
print("b value is %d and c value is %d" %(b,c))
# Out:
# a value is 10
# b value is 20 and c value is 30

# %%
name="Vijay"
salary=30000
company="TCS"
print("Hello {0} your salary is {1} and Company {2}".format(name, salary,company))
print("Hello {x} your salary is {y} and Company {z}".format(x=name,y=salary, z=company))
# Out:
# Hello Vijay your salary is 30000 and Company TCS
# Hello Vijay your salary is 30000 and Company TCS

# %%
a=int(input("Enter a Value:"))
a%10
# Out:
# Enter a Value:46647
# 7

# %%
a=input("Enter a Value:")
a[-1]
# Out:
# Enter a Value:46647
# '7'

# %%
no=int(input("Enter no: "))
n1=no%10
no=no//10
n2=no%10
no=no//10
n3=no%10
res=n1+n2+n3
print("sum of 3 digit is" ,res)
# Out:
# Enter no: 123
# sum of 3 digit is 6

# %%
no = int(input("Enter a five-digit number: "))
n1 = no % 10 #5
no = no // 10 #1234
n2 = no % 10 #4
no = no // 10 #123
n3 = no % 10 #3
no = no // 10 #12
n4 = no % 10 #2
no = no // 10 #1
n5 = no % 10 #1
res = n1 + n2 + n3 + n4 + n5
print("Sum of digits is", res)
# Out:
# Enter a five-digit number: 54321
# Sum of digits is 15

# %%
n=int(input('enter the number'))
sum=0
while(n!=0):
  sum=sum+n%10
  n=n//10
print(sum)
# Out:
# enter the number1234
# 10

# %%
no = int(input("Enter a five-digit number: "))
n1 = no % 10 #5
no = no // 10 #1234
n2 = no % 10 #4
no = no // 10 #123
n3 = no % 10 #3
no = no // 10 #12
n4 = no % 10 #2
no = no // 10 #1
n5 = no % 10 #1
res = n1*10000 + n2*1000 + n3*100 + n4*10 + n5
print("Sum of digits is", res)
# Out:
# Enter a five-digit number: 12345
# Sum of digits is 54321

# %%
no = input("Enter a nine-digit number: ")
int(no[-1])+int(no[0])
# Out:
# Enter a nine-digit number: 123456789
# 10

# %%
#slicing
#[start:end:step]
s="Gadpayle"
s[0:2]+"n"+s[2:8]
# Out:
# 'Gandpayle'

# %%
n1 = int(input("Enter first number: "))
n2 = int(input("Enter second number: "))
n3 = int(input("Enter third number: "))
n4 = int(input("Enter fourth number: "))
n5 = int(input("Enter fifth number: "))
max=n1
if n2 > max:
  max = n2
if n3 > max:
  max = n3
if n4 > max:
  max = n4
if n5 > max:
  max = n5

print("The maximum number is:", max)
# Out:
# Enter first number: 2
# Enter second number: 0
# Enter third number: 7
# Enter fourth number: 6
# Enter fifth number: 5
# The maximum number is: 7

# %%
m1=int(input("Enter marks of first subject: "))
m2=int(input("Enter marks of second subject: "))
m3=int(input("Enter marks of third subject: "))
sex=input("enter the sex in m/f: ")
per=6(m1+m2+m3)/3
if(per>=82 and sex=="f"):
  print("She can take admission")
elif(per>=62 and sex=="m"):
  print("He can take admission")
else:
  print("Can't take admission")
# Out:
# Enter marks of first subject: 62
# Enter marks of second subject: 62
# Enter marks of third subject: 62
# enter the sex in m/f: m
# He can take admission
# 62.0

# %%
year = int(input("Enter a year: "))
if (year % 4 == 0 and year % 100 != 0):
    print(f"{year} is a non century leap year.")
elif (year % 400 == 0):
    print(f"{year} is a century leap year.")
else:
    print(f"{year} is not a leap year.")
# Out:
# Enter a year: 2000
# 2000 is a century leap year.

# %%
cp=int(input("Enter the cost price : "))
s=input("user is student yes/no")
if(s=="yes" and cp>500):
  cp=cp-cp*.10
  print(f"discount is 10% {cp}")
elif(s=="no" and c>500):
  cp=cp-cp*.08
  print(f"discount is 8% {cp}")
elif(s=="yes" and cp<500):
  cp=cp-cp*.05
  print(f"discount is 5% {cp}")

else:
  cp=cp-cp*.02
  print(f"discount is 2% {cp}")
# Out:
# Enter the cost price : 501
# user is student yes/noyes
# discount is 10% 450.9

# %%
n=input("Enter a number: ")
n=ord(n)
if n>=65 and n<=90:
  print(f"{n} is a capital letter")
elif n>=97 and n<=122:
  print(f"{n} is a small letter")
elif n>=48 and n<=57:
  print(f"{n} is a number")
else:
  print(f"{n} is a special character")
# Out:
# Enter a number: A
# 65 is a capital letter

# %%
#for loop is used when range is given
#while loop is used when range is not given

# %%
n=int(input('enter the number '))
rev=0
while(n!=0):
  rev=rev*10+n%10
  n=n//10
print(f"{rev} is the reverse number ")
# Out:
# enter the number 987654321
# 123456789 is the reverse number

# %%
#basic practice
"""Accept a number and count number of digits
entered by user.
Accept a number and print sum of digits of
any number.
Accept a number and find multiplication of
any number.
Accept a number and find factorial of any
number."""
# Out:
# 'Accept a number and count number of digits\nentered by user.\nAccept a number and print sum of digits of\nany number.\nAccept a number and find multiplication of\nany number.\nAccept a number and find factorial of any\nnumber.'

# %%
n=int(input("enter the number "))
c=0
while(n!=0):
  c=c+1
  n=n//10
print(f"{c} is the number of digits")
# Out:
# enter the number123
# 3 is the number of digits

# %%
n=int(input("enter the number "))
sum=0
while(n!=0):
  sum=sum+n%10
  n=n//10
print(f"{sum} is the sum of digits")
# Out:
# enter the number 123
# 6 is the sum of digits

# %%
n=int(input("enter the number "))
mul=1
while(n!=0):
  mul=mul*n%10
  n=n//10
print(f"{mul} is the mul of digits")
# Out:
# enter the number 123
# 6 is the sum of digits

# %%
n=int(input("enter the number "))
fact=1
while(n!=0):
  fact=fact*n
  n=n-1
print(f"{fact} is the fact of digits")
# Out:
# enter the number 5
# 120 is the sum of digits

# %%
num=int(input("enter the number "))
n=num
c=0
while(n!=0):
  c=c+1
  n=n//10
n=num
while(n!=0):
  sum=sum+pow(n%10,c)
  n=n//10
if(sum==num):
  print("armstrong number")
else:
  print("not armstrong number")
# Out:
# enter the number 153
# armstrong number

# %%
#armstrong
for i in range(1,10000):
  n=i
  c=0
  sum=0
  while(n>0):
    c=c+1
    n=n//10
  n=i
  while(n>0):
    sum=sum+pow(n%10,c)
    n=n//10
  if(sum==i):
    print(sum)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 153
# 370
# 371
# 407
# 1634
# 8208
# 9474

# %%
#peterson
num=int(input("enter the number "))
sum=0
n=num
while(n>0):
    rem=n%10
    fact=1
    while(rem>0):
      fact=fact*rem
      rem=rem-1
    n=n//10
    sum=fact+sum
print(sum)
if(sum==num):
  print("peterson number")
else:
  print("not peterson number")
# Out:
# enter the number 145
# 145
# peterson number

# %% [markdown]
# Tech Number
# A number is called a tech number if the given number has an
# even number of digits and the number can be divided exactly
# into two parts from the middle. After equally dividing the
# number, sum up the numbers and find the square of the sum.
# If we get the number itself as square, the given number is a
# tech number, else, not a tech number.
# For example, 2025is a tech number.

# %%
#slicing method
num = input("Enter the number: ")
n = len(num)
if(n%2==0):
  strt=num[0:n//2]
  end=num[n//2:n+1]
  techn=int(strt)+int(end)
  techn=techn*techn
  if(techn==int(num)):
    print("tech number")
  else:
    print("not tech number")
else:
    print("not tech number")
# Out:
# Enter the number: 2025
# tech number

# %%
#count method
num = input("Enter the number: ")
n = len(num)

num=int(num)
if(n%2==0):
  strt=num//10**(n//2)
  end=num%10**(n//2)
  techn=strt+end
  techn=techn**2
  if(techn==num):
    print("tech number")
  else:
    print("not tech number")
else:
    print("not tech number")
# Out:
# Enter the number: 2025
# tech number
